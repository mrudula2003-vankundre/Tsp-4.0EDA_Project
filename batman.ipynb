# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\mrudu\Downloads\archive (1).zip")

# %%
df
# Out:
#     Year                                    Title    Rated  \
# 0   1989                                   Batman    PG-13
# 1   1992                           Batman Returns    PG-13
# 2   1993             Batman: Mask of the Phantasm       PG
# 3   1995                           Batman Forever    PG-13
# 4   1997                           Batman & Robin    PG-13
# 5   1998             Batman & Mr. Freeze: SubZero  Unrated
# 6   2000       Batman Beyond: Return of the Joker    PG-13
# 7   2005                            Batman Begins    PG-13
# 8   2008                          The Dark Knight    PG-13
# 9   2010               Batman: Under the Red Hood    PG-13
# 10  2011                         Batman: Year One    PG-13
# 11  2012  Batman: The Dark Knight Returns, Part 1    PG-13
# 12  2012                    The Dark Knight Rises    PG-13
# 13  2013  Batman: The Dark Knight Returns, Part 2    PG-13
# 14  2014                Batman: Assault on Arkham    PG-13
# ...

# %%
df.head()
# Out:
#    Year                         Title  Rated  \
# 0  1989                        Batman  PG-13
# 1  1992                Batman Returns  PG-13
# 2  1993  Batman: Mask of the Phantasm     PG
# 3  1995                Batman Forever  PG-13
# 4  1997                Batman & Robin  PG-13
#
#                                             Director    Released  \
# 0                                         Tim Burton   6/23/1989
# 1                                         Tim Burton   6/19/1992
# 2  Eric Radomski, Bruce Timm, Kevin Altieri, Boyd...  12/25/1993
# 3                                    Joel Schumacher   6/16/1995
# 4                                    Joel Schumacher   6/20/1997
#
#                                               Writer             Production  \
# 0  Bob Kane (Batman characters), Sam Hamm (story)...  Warner Bros. Pictures
# 1  Bob Kane (Batman characters), Daniel Waters (s...  Warner Bros. Pictures
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Title', 'Rated', 'Director', 'Released', 'Writer',
#        'Production', 'Actors', 'Runtime', 'Awards', 'Imdb Votes',
#        'Imdb Rating', 'RottenTomatoScore', 'Metascore'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               19 non-null     int64
#  1   Title              19 non-null     object
#  2   Rated              19 non-null     object
#  3   Director           19 non-null     object
#  4   Released           19 non-null     object
#  5   Writer             19 non-null     object
#  6   Production         19 non-null     object
#  7   Actors             19 non-null     object
#  8   Runtime            19 non-null     object
#  9   Awards             19 non-null     object
#  10  Imdb Votes         19 non-null     object
#  11  Imdb Rating        19 non-null     float64
#  12  RottenTomatoScore  18 non-null     object
#  13  Metascore          9 non-null      float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 2.2+ KB

# %%
df.describe()
# Out:
#               Year  Imdb Rating  Metascore
# count    19.000000    19.000000   9.000000
# mean   2006.105263     7.226316  59.666667
# std       9.579461     1.221948  18.472953
# min    1989.000000     3.700000  28.000000
# 25%    1997.500000     6.600000  45.000000
# 50%    2010.000000     7.500000  68.000000
# 75%    2013.500000     8.000000  70.000000
# max    2018.000000     9.000000  84.000000

# %%
df.columns
# Out:
# Index(['Year', 'Title', 'Rated', 'Director', 'Released', 'Writer',
#        'Production', 'Actors', 'Runtime', 'Awards', 'Imdb Votes',
#        'Imdb Rating', 'RottenTomatoScore', 'Metascore'],
#       dtype='object')

# %%
plt.figure(figsize=(9,4))
plt.scatter(df['Year'],df['Director'])
plt.xlabel("Year")
plt.ylabel("Director")
plt.show()

# %%
def bar_plot(variable):
    var=df [variable]
    varValue=var.value_counts()
    plt.figure(figsize=(8,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
df.columns
# Out:
# Index(['Year', 'Title', 'Rated', 'Director', 'Released', 'Writer',
#        'Production', 'Actors', 'Runtime', 'Awards', 'Imdb Votes',
#        'Imdb Rating', 'RottenTomatoScore', 'Metascore'],
#       dtype='object')

# %%
columns_plot=['Year', 'Title', 'Director', 'Awards',
       'Released']
for i in columns_plot:
    bar_plot(i)
# Out:
# Year:
#  Year
# 2016    2
# 2012    2
# 1989    1
# 2010    1
# 2017    1
# 2014    1
# 2013    1
# 2011    1
# 2008    1
# 1992    1
# 2005    1
# 2000    1
# 1998    1
# 1997    1
# 1995    1
# 1993    1
# 2018    1
# Name: count, dtype: int64
# Title:
#  Title
# Batman                                     1
# Batman: Year One                           1
# Justice League                             1
# Batman: The Killing Joke                   1
# Batman v Superman                          1
# Batman: Assault on Arkham                  1
# Batman: The Dark Knight Returns, Part 2    1
# The Dark Knight Rises                      1
# Batman: The Dark Knight Returns, Part 1    1
# Batman: Under the Red Hood                 1
# Batman Returns                             1
# The Dark Knight                            1
# Batman Begins                              1
# Batman Beyond: Return of the Joker         1
# Batman & Mr. Freeze: SubZero               1
# ...

# %%
plt.hist(df['Title'])
plt.show()

# %%
def hist_plot(variable):
    var=df [variable]
    varValue=var.value_counts()
    plt.figure(figsize=(8,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
columns_plot=['Title','Runtime']
for i in columns_plot:
    hist_plot(i)
# Out:
# Title:
#  Title
# Batman                                     1
# Batman: Year One                           1
# Justice League                             1
# Batman: The Killing Joke                   1
# Batman v Superman                          1
# Batman: Assault on Arkham                  1
# Batman: The Dark Knight Returns, Part 2    1
# The Dark Knight Rises                      1
# Batman: The Dark Knight Returns, Part 1    1
# Batman: Under the Red Hood                 1
# Batman Returns                             1
# The Dark Knight                            1
# Batman Begins                              1
# Batman Beyond: Return of the Joker         1
# Batman & Mr. Freeze: SubZero               1
# Batman & Robin                             1
# Batman Forever                             1
# Batman: Mask of the Phantasm               1
# Batman: Gotham by Gaslight                 1
# Name: count, dtype: int64
# Runtime:
#  Runtime
# 76 min     6
# 126 min    2
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Title', 'Rated', 'Director', 'Released', 'Writer',
#        'Production', 'Actors', 'Runtime', 'Awards', 'Imdb Votes',
#        'Imdb Rating', 'RottenTomatoScore', 'Metascore'],
#       dtype='object')

# %%
df[['Year','Title']].groupby(['Year'],as_index=False).count().sort_values(by='Title',ascending=False)
# Out:
#     Year  Title
# 14  2016      2
# 11  2012      2
# 0   1989      1
# 9   2010      1
# 15  2017      1
# 13  2014      1
# 12  2013      1
# 10  2011      1
# 8   2008      1
# 1   1992      1
# 7   2005      1
# 6   2000      1
# 5   1998      1
# 4   1997      1
# 3   1995      1
# 2   1993      1
# 16  2018      1

# %%
sns.boxplot(df['Year'])
# Out:
# <Axes: ylabel='Year'>

# %%
sns.boxplot(df['Runtime'])
# Out:
# <Axes: ylabel='Runtime'>

# %%
df['Year']=df['Year'].fillna(df['Year'].median())

# %%
df.isnull().sum()
# Out:
# Year                  0
# Title                 0
# Rated                 0
# Director              0
# Released              0
# Writer                0
# Production            0
# Actors                0
# Runtime               0
# Awards                0
# Imdb Votes            0
# Imdb Rating           0
# RottenTomatoScore     1
# Metascore            10
# dtype: int64

# %%
df['Year'].mode()
# Out:
# 0    2012
# 1    2016
# Name: Year, dtype: int64

# %%
df['Year']=df['Year'].fillna(df['Year'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Year                  0
# Title                 0
# Rated                 0
# Director              0
# Released              0
# Writer                0
# Production            0
# Actors                0
# Runtime               0
# Awards                0
# Imdb Votes            0
# Imdb Rating           0
# RottenTomatoScore     1
# Metascore            10
# dtype: int64

# %%
df.drop(labels=[ 'Year','Director','Production',],axis=1,inplace=True)

# %%
df.head()
# Out:
#                           Title  Rated    Released  \
# 0                        Batman  PG-13   6/23/1989
# 1                Batman Returns  PG-13   6/19/1992
# 2  Batman: Mask of the Phantasm     PG  12/25/1993
# 3                Batman Forever  PG-13   6/16/1995
# 4                Batman & Robin  PG-13   6/20/1997
#
#                                               Writer  \
# 0  Bob Kane (Batman characters), Sam Hamm (story)...
# 1  Bob Kane (Batman characters), Daniel Waters (s...
# 2  Bob Kane (character created by: Batman), Alan ...
# 3  Bob Kane (characters), Lee Batchler (story), J...
# 4       Bob Kane (Batman characters), Akiva Goldsman
#
#                                               Actors  Runtime  \
# 0  Michael Keaton, Jack Nicholson, Kim Basinger, ...  126 min
# 1  Michael Keaton, Danny DeVito, Michelle Pfeiffe...  126 min
# 2  Kevin Conroy, Dana Delany, Hart Bochner, Stacy...   76 min
# 3  Val Kilmer, Tommy Lee Jones, Jim Carrey, Nicol...  121 min
# ...

# %%
df = pd.concat([df, pd.get_dummies(df['Rated'], drop_first=True)], axis=1)

# %%
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True, fmt='.2f')
plt.show()

# %%
plt.subplot(3,2,1)
plt.title('Year')
plt.hist(df['Year'])
plt.subplot(3,2,2)
plt.title('Director')
plt.hist(df['Director'])
plt.subplot(3,2,5)
plt.title('Awards')
plt.hist(df['Awards'])
plt.subplot(3,2,6)
plt.title('Runtime')
plt.hist(df['Runtime'])
plt.show()

# %%
sns.violinplot(x='Year',y='Awards',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Awards'>

# %%
sns.pairplot(df)

# %%
Year=np.array([1,2,3,4,5])
Title=np.array([5.1,4.9,4.7,4.6,5.0])
plt.pie(Title,labels=Year)
# Out:
# ([<matplotlib.patches.Wedge at 0x20671cc2030>,
# ...
#  [Text(0.869431917387439, 0.6738606243341435, '1'),
#   Text(-0.4094288470404943, 1.0209642595169979, '2'),
#   Text(-1.09852946383526, -0.056859626149108035, '3'),
#   Text(-0.3426223903931884, -1.0452798178484353, '4'),
#   Text(0.8780711131409357, -0.6625640499358821, '5')])

# %%
sns.lmplot(x='Year',y='Metascore',data=df)

# %%
sns.boxplot(x='Year',y='Runtime',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Runtime'>
